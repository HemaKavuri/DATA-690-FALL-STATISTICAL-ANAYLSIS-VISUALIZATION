# %% [markdown]
# <a href="https://colab.research.google.com/github/HemaKavuri/DATA-690-FALL-STATISTICAL-ANAYLSIS-VISUALIZATION/blob/main/Assignment_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Libraries

# %%
import pandas as pd
import re

# %%
# Reading Data File
college=pd.read_csv("/content/MERGED2017_18_PP.csv") 
college
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (1729) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         UNITID    OPEID  OPEID6  \
# 0       100654   100200    1002
# 1       100663   105200    1052
# 2       100690  2503400   25034
# 3       100706   105500    1055
# 4       100724   100500    1005
# ...        ...      ...     ...
# 7107  48312404   108163    1081
# 7108  48387801  4223701   42237
# 7109  48400201  4228101   42281
# 7110  48778201  4221501   42215
# 7111  49005401  4182601   41826
#
#                                                  INSTNM             CITY  \
# 0                              Alabama A & M University           Normal
# 1                   University of Alabama at Birmingham       Birmingham
# 2                                    Amridge University       Montgomery
# ...

# %% [markdown]
# 1. how many colleges or rows?

# %% [markdown]
# Number Of Rows

# %%
rows = college.shape[0]
rows
# Out:
# 7112

# %% [markdown]
# But their can be duplicate Rows in the given dataframe so I also considered number of unique colleges from the dataframe.

# %% [markdown]
# Number of Colleges

# %%
college['INSTNM'].nunique()
# Out:
# 6974

# %% [markdown]
# 2. how many variables or columns?

# %% [markdown]
# Number Columns

# %%
columns=college.shape[1]
columns
# Out:
# 1986

# %% [markdown]
# 3. Look at the first 5 colleges

# %%
college.head(5)
# Out:
#    UNITID    OPEID  OPEID6                               INSTNM        CITY  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
# 3  100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 4  100724   100500    1005             Alabama State University  Montgomery
#
#   STABBR         ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 0     AL       35762           NaN      NaN     NaN  ...
# 1     AL  35294-0110           NaN      NaN     NaN  ...
# 2     AL  36117-3553           NaN      NaN     NaN  ...
# 3     AL       35899           NaN      NaN     NaN  ...
# 4     AL  36104-0271           NaN      NaN     NaN  ...
#
#    OMENRUP_PARTTIME_POOLED_SUPP  FTFTPCTPELL  FTFTPCTFLOAN   UG12MN   G12MN  \
# 0                           NaN       0.7106        0.7418   5207.0  1185.0
# ...

# %% [markdown]
# 5. look at the last 5 colleges

# %%
college.tail(5)
# Out:
#         UNITID    OPEID  OPEID6  \
# 7107  48312404   108163    1081
# 7108  48387801  4223701   42237
# 7109  48400201  4228101   42281
# 7110  48778201  4221501   42215
# 7111  49005401  4182601   41826
#
#                                                  INSTNM             CITY  \
# 7107                   Arizona State University at Yuma             Yuma
# 7108  Bay Area Medical Academy - San Jose Satellite ...         San Jose
# 7109           High Desert Medical College - Bakerfield      Bakersfield
# 7110                                       BCI - Malden           Malden
# 7111               HCI College - Fort Lauderdale Campus  Fort Lauderdale
#
#      STABBR        ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 7107     AZ  853656900           NaN      NaN     NaN  ...
# 7108     CA      95113           NaN      NaN     NaN  ...
# 7109     CA      93301           NaN      NaN     NaN  ...
# 7110     MA  021480000           NaN      NaN     NaN  ...
# ...

# %% [markdown]
# Look at a random sample of 5 colleges ?

# %%
sample_colleges=college.sample(n=5)
sample_colleges
# Out:
#       UNITID    OPEID  OPEID6  \
# 4705  431266  2242400   22424
# 6139  481289  4211900   42119
# 285   113333   448000    4480
# 5547  456153  4129802   41298
# 6349  485236  4236800   42368
#
#                                                  INSTNM       CITY STABBR  \
# 4705  Henrico County-Saint Marys Hospital School of ...    Henrico     VA
# 6139                   Xavier College School of Nursing   Stockton     CA
# 285                                     De Anza College  Cupertino     CA
# 5547                        MediaTech Institute-Houston    Houston     TX
# 6349           Fountain of Youth Academy of Cosmetology       Mars     PA
#
#              ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 4705       23294           NaN      NaN     NaN  ...
# 6139  95202-1017           NaN      NaN     NaN  ...
# 285        95014           NaN      NaN     NaN  ...
# 5547       77042           NaN      NaN     NaN  ...
# 6349       16046           NaN      NaN     NaN  ...
#
# ...

# %% [markdown]
# 7. Since there are too many variables to explore, many of which are not interesting. Create a smaller data frame with the following 9 variables:
#   UNITID
#
#   INSTNM
#
#   CITY
#
#   STABBR
#
#   ZIP
#
#   ADM_RATE
#
#   UGDS
#
#   TUITIONFEE_IN
#
#   MN_EARN_WNE_P10
#
#   Taking the subset of above mentioned columns.

# %%
college_sub_df=college[['UNITID','INSTNM','CITY','STABBR','ZIP','ADM_RATE','UGDS','TUITIONFEE_IN','MN_EARN_WNE_P10']]
college_sub_df
# Out:
#         UNITID                                             INSTNM  \
# 0       100654                           Alabama A & M University
# 1       100663                University of Alabama at Birmingham
# 2       100690                                 Amridge University
# 3       100706                University of Alabama in Huntsville
# 4       100724                           Alabama State University
# ...        ...                                                ...
# 7107  48312404                   Arizona State University at Yuma
# 7108  48387801  Bay Area Medical Academy - San Jose Satellite ...
# 7109  48400201           High Desert Medical College - Bakerfield
# 7110  48778201                                       BCI - Malden
# 7111  49005401               HCI College - Fort Lauderdale Campus
#
#                  CITY STABBR         ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  \
# 0              Normal     AL       35762    0.9027   4824.0         9857.0
# ...

# %% [markdown]
# 8. Download and read (use naked eyes, no coding) the data dictionary file -
# 9. Find out the definition of the above 9 variables and document the definitions in the Jupyter Notebook in a Markdown cell so that the readers of your notebook will know the meaning of these variables.

# %% [markdown]
# **UNITID** - Stores Unique identification number for each university in the data frame
#
# **INSTNM** - Stores University Name
#
# **CITY** - It stores in which city does the University is located
#
# **STABBR** - It stores the State Abbrevation
#
# **ZIP** - It stores the Zipcode  where the insititue is located
#
# **ADM_RATE** - It stores the Admission Rate of the Universities
#
# **UGDS** - It stores the Number of Undergrade students data enrolled in the University
#
# **TUITIONFEE_IN** - It stores the In-state Tuition fee data for the Universities.
#
# **MN_EARN_WNE_P10** - This column stores the mean earnings of graduates working since 10 years.

# %% [markdown]
# 10. Explore the smaller data frame
#
#        a. Look at the first 10 colleges

# %%
college_sub_df.head(10)
# Out:
#    UNITID                               INSTNM            CITY STABBR  \
# 0  100654             Alabama A & M University          Normal     AL
# 1  100663  University of Alabama at Birmingham      Birmingham     AL
# 2  100690                   Amridge University      Montgomery     AL
# 3  100706  University of Alabama in Huntsville      Huntsville     AL
# 4  100724             Alabama State University      Montgomery     AL
# 5  100751            The University of Alabama      Tuscaloosa     AL
# 6  100760    Central Alabama Community College  Alexander City     AL
# 7  100812              Athens State University          Athens     AL
# 8  100830      Auburn University at Montgomery      Montgomery     AL
# 9  100858                    Auburn University          Auburn     AL
#
#           ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 0       35762    0.9027   4824.0         9857.0              NaN
# 1  35294-0110    0.9181  12866.0         8328.0              NaN
# ...

# %% [markdown]
# b. look at the last 10 colleges

# %%
college_sub_df.tail(10)
# Out:
#         UNITID                                             INSTNM  \
# 7102  48154401  National Personal Training Institute of Cleveland
# 7103  48305401             Barber School of Pittsburgh - Ambridge
# 7104  48312401                 Arizona State University at Tucson
# 7105  48312402  Arizona State University - ASU Colleges at Lak...
# 7106  48312403        Arizona State University at The Gila Valley
# 7107  48312404                   Arizona State University at Yuma
# 7108  48387801  Bay Area Medical Academy - San Jose Satellite ...
# 7109  48400201           High Desert Medical College - Bakerfield
# 7110  48778201                                       BCI - Malden
# 7111  49005401               HCI College - Fort Lauderdale Campus
#
#                   CITY STABBR        ZIP  ADM_RATE  UGDS  TUITIONFEE_IN  \
# 7102  Highland Heights     OH      44143       NaN   NaN            NaN
# 7103          Ambridge     PA  150030000       NaN   NaN            NaN
# ...

# %% [markdown]
# c. Look at a random sample of 10 colleges

# %%
college_sub_df.sample(n=10)
# Out:
#         UNITID                                 INSTNM          CITY STABBR  \
# 1901    177870       Lake Career and Technical Center     Camdenton     MO
# 16      101189                    Faulkner University    Montgomery     AL
# 5968    475431                   ASI Career Institute  Turnersville     NJ
# 4878    440323            Brightwood College-Beaumont      Beaumont     TX
# 3657    232450           John Tyler Community College       Chester     VA
# 5373    451352       Southeastern Institute-Charlotte     Charlotte     NC
# 5324    450377             Strayer University-Alabama    Birmingham     AL
# 3184    216931                      Wilkes University  Wilkes-Barre     PA
# 6814  16947909  Davenport University-Holland Location       Holland     MI
# 4391    403469             Frontier Community College     Fairfield     IL
#
#              ZIP  ADM_RATE    UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1901       65020       NaN    15.0         4500.0              NaN
# ...

# %% [markdown]
# d. Find and display UMBC

# %% [markdown]
# We need to know how the institute name is written inside the data frame. So to find it I selcted City=='Baltimore', from that i have taken university name.

# %%
college_sub_df.loc[college_sub_df['CITY']=='Baltimore']
# Out:
#         UNITID                                   INSTNM       CITY STABBR  \
# 1451    161855          Baltimore Studio of Hair Design  Baltimore     MD
# 1452    161864         Baltimore City Community College  Baltimore     MD
# 1453    161873                  University of Baltimore  Baltimore     MD
# 1460    162283                  Coppin State University  Baltimore     MD
# 1462    162371             North American Trade Schools  Baltimore     MD
# 1466    162654                          Goucher College  Baltimore     MD
# 1473    162928                 Johns Hopkins University  Baltimore     MD
# 1475    163046               Loyola University Maryland  Baltimore     MD
# 1477    163259         University of Maryland Baltimore  Baltimore     MD
# 1478    163268  University of Maryland-Baltimore County  Baltimore     MD
# 1480    163295        Maryland Institute College of Art  Baltimore     MD
# 1485    163453                  Morgan State University  Baltimore     MD
# ...

# %%
college1=college_sub_df.loc[college_sub_df['INSTNM']=='University of Maryland-Baltimore County']
college1
# Out:
#       UNITID                                   INSTNM       CITY STABBR  \
# 1478  163268  University of Maryland-Baltimore County  Baltimore     MD
#
#         ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1478  21250    0.6021  11130.0        11518.0              NaN

# %% [markdown]
# e. Find Univ. of Maryland College Park

# %%
college2=college_sub_df.loc[college_sub_df['CITY']=='College Park']
college2
# Out:
#       UNITID                               INSTNM          CITY STABBR    ZIP  \
# 1479  163286  University of Maryland-College Park  College Park     MD  20742
#
#       ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1479     0.445  29273.0        10399.0              NaN

# %% [markdown]
# f. Find and display Loyola College Maryland

# %%
college3=college_sub_df.loc[college_sub_df['INSTNM']=='Loyola University Maryland']
college3
# Out:
#       UNITID                      INSTNM       CITY STABBR         ZIP  \
# 1475  163046  Loyola University Maryland  Baltimore     MD  21210-2699
#
#       ADM_RATE    UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1475    0.7528  3903.0        47560.0              NaN

# %% [markdown]
# g. Find and display Johns Hopskins

# %%
college4=college_sub_df.loc[college_sub_df['INSTNM']=='Johns Hopkins University']
college4
# Out:
#       UNITID                    INSTNM       CITY STABBR         ZIP  \
# 1473  162928  Johns Hopkins University  Baltimore     MD  21218-2688
#
#       ADM_RATE    UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1473    0.1254  5663.0        52170.0              NaN

# %% [markdown]
# f. Calculate the min, max, and average in-state tution of the above four institutions.

# %%
Institutions=pd.concat([college1,college2,college3,college4])
Institutions
# Out:
#       UNITID                                   INSTNM          CITY STABBR  \
# 1478  163268  University of Maryland-Baltimore County     Baltimore     MD
# 1479  163286      University of Maryland-College Park  College Park     MD
# 1475  163046               Loyola University Maryland     Baltimore     MD
# 1473  162928                 Johns Hopkins University     Baltimore     MD
#
#              ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1478       21250    0.6021  11130.0        11518.0              NaN
# 1479       20742    0.4450  29273.0        10399.0              NaN
# 1475  21210-2699    0.7528   3903.0        47560.0              NaN
# 1473  21218-2688    0.1254   5663.0        52170.0              NaN

# %% [markdown]
# Minimum In-State Tution Fee

# %%
Institutions['TUITIONFEE_IN'].min()
# Out:
# 10399.0

# %% [markdown]
# Maximum In-State Tution Fee

# %%
Institutions['TUITIONFEE_IN'].max()
# Out:
# 52170.0

# %% [markdown]
# Average Tution Fee

# %%
Institutions['TUITIONFEE_IN'].mean()
# Out:
# 30411.75

# %% [markdown]
# 11. Filter the smaller dataset further to only keep colleges from Maryland, Virgina, Washington DC, Delaware, and Pennsylvinia. Save the filtered dataset to a new file named "Five_States_Colleges.csv" for future analysis. Upload this file to your GitHub along with the notebook.

# %%
States=['MD','VA','DC','DE','PA']
Five_States_Colleges=college_sub_df.loc[college_sub_df['STABBR'].isin(States)]
Five_States_Colleges
# Out:
#         UNITID                                             INSTNM  \
# 634     130837  Margaret H Rollins School of Nursing at Beebe ...
# 635     130873                          Dawn Career Institute LLC
# 636     130907         Delaware Technical Community College-Terry
# 637     130934                          Delaware State University
# 638     130943                             University of Delaware
# ...        ...                                                ...
# 7063  45794301   Somerset County Technology Center - Bedford Site
# 7084  47503303      Relay Graduate School of Education - Delaware
# 7089  47503308  Relay Graduate School of Education - Philadelp...
# 7094  47503313  Relay Graduate School of Education - Washingto...
# 7103  48305401             Barber School of Pittsburgh - Ambridge
#
#               CITY STABBR        ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  \
# 634          Lewes     DE      19958       NaN     59.0            NaN
# ...

# %%
Five_States_Colleges['STABBR'].nunique()
# Out:
# 5

# %%
Five_States_Colleges.to_csv('Five_States_Colleges.csv')
